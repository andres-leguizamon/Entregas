# %% [markdown]
# #      Introducción a las Derivadas

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ![Logo%20python.png](attachment:Logo%20python.png)

# %% [markdown]
# ## Autor
# 1.Andrés Leguizamón
# ![WhatsApp%20Image%202023-08-01%20at%204.58.16%20PM.jpeg](attachment:WhatsApp%20Image%202023-08-01%20at%204.58.16%20PM.jpeg)
# Estudiante de Economía de la Universidad Nacional de Colombia. Interesado en el análisis de datos

# %% [markdown]
# ## Presentación
# La derivada es un concepto que surge de un problema geométrico esencial, el problema de hallar el la tangente en un punto a una curva. Sin embargo, a partir de las elaboraciones de autores posteriores, el concepto de derivada quedo estrechamente relacionado a un problema de velocidad, de hecho , la intuición de la derivada se puede deducir a partir del concepto de velocidad en un instante.

# %% [markdown]
# ## Velocidad en un instante y velocidad media
# Suponga que queremos comparar como cambia la velocidad de un objeto cuando nos movemos entre dos momentos del tiempo , un momento inicial $t$ y un momento final $h$ segundos después de t, de la misma forma , podemos asumir que existe una función $d(x)$ que nos dice a que distancia se encuentra el objeto en cada momento del tiempo. \
# **Tendríamos los siguientes elementos:** \
# Tiempo Inicial: $t$ \
# Tiempo final : $t+h$  \
# Posición inicial del objeto : $f(t)$ \
# Posicion final del objeto : $f(t+h)$ \
#
# Para determinar la velocidad media entre estos momentos del tiempo se puede plantear el cociente  $\frac{{f(t+h)-f(t)}}{{h}}$
# Cuando planteemos el limite cuando h tiende a 0 , podemos notar que los dos momentos de comparación se van acercando hasta que se convierten en el mismo momento, por lo cual nuestra velocidad media se comezaria a acerca a la velocidad instantanea cuanto menor sea el cambio. \
# Cuando estamos evaluando este limite para encontrar la velocidad instantanea, estamos encontrando la derivada de la función.

# %% [markdown]
# ## Ejemplo:
# Suponga que nuestra función de velocidad es un polinomio de la forma $f(x)$= $a_nx^n+a_{n-1}x^{n-1}...a_{2}x^{2}+a_{1}x^{1}+a_{0}x^{0}$ \
# Si quisieramos encontrar la derivada , o mejor dicho , la velocidad instantanea en un punto , tendriamos que plantear el limite: \
#
# $\large\lim_{{h \to 0}} \frac{f(x+h)-f(x)}{h}\$ \
#
# Reemplazando la forma de la función
#
#
# $\large\lim_{{h \to 0}} \frac{a_n(x+h)^n+a_{n-1}(x+h)^{n-1}...a_{2}(x+h)^{2}+a_{1}(x+h)^{1}+a_{0}(x+h)^{0}  -a_nx^n+a_{n-1}x^{n-1}...a_{2}x^{2}+a_{1}x^{1}+a_{0}x^{0}}{h}\$ \
#
# Al resolver algebraicamente esta suma tendremos que el resultado final es $\sum_{k=0}^{m} k a_{k}x^{k-1}$

# %% [markdown]
# ## Referencias
# 1.[ Apostol, T. M. (2019). Calculus. Wiley Global Education.](https://calculounicaes.files.wordpress.com/2012/04/calculo-volumen-1-de-tom-apostol.pdf)

# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/andres-leguizamon/Entregas/blob/master/Tarea2.ipynb)
